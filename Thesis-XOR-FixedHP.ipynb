# %%
#Classification of XOR dataset 
using Gen
using PyPlot
using Distributions
using LinearAlgebra
using Random
using Distances
using Flux
using StatsBase
using MultivariateStats
using MLDatasets

include("dockeropt/proposals.jl")
include("dockeropt/utils.jl");

# %%
#------------------------------------
#Hyperparameters and Helper Functions
#------------------------------------

#Select Network Goal
network = "classifier"

#Data hyperparameters
c = 2
n = 50 #Number of samples per mode (classifier)
m = 4 #Number of modes (classifier)
d = 2 #Input dimension
N = n*m #Total samples
σₐ = 0.1 #Mode variance (classifier)
bound = 0.5

#Node hyperparameters
k_range = 16 #Maximum number of neurons per layer
k_list = [Int(i) for i in 1:k_range]

#NUTS
Δ_max = 1000;

x_raw, classes = real_data_classifier(Int(N/4), 4, bound, σₐ);
classes = [(i+1) % 2 + 1 for i in classes]
y = classes

plot_data_classifier(x_raw,classes)
xt = transpose(x_raw)
size(xt)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (2, 200)

# %%
#One-Hot Encode Y
yt = Flux.onehotbatch(y,[:1,:2]);

#Test Set
x_raw_test, classes_test = real_data_classifier(Int(N/4), 4, bound, σₐ);
xt_test = transpose(x_raw_test)
classes_test = [(i+1) % 2 + 1 for i in classes]
y_test = classes_test
yz = y_test
yzt = Flux.onehotbatch(yz,[:1,:2]);

# %%
function softmax_(arr::AbstractArray)
    ex = mapslices(x -> exp.(0.9.*x),arr,dims=1)
    rows, cols = size(arr)
    val = similar(ex)
    for i in 1:cols
        s = sum(ex[:,i])
        for j in 1:rows
            val[j,i] = ex[j,i]/s
        end
    end
    return val
end;

#Bayesian Neural Net
function G(x, trace)
    activation = tanh
    layers = trace[:l]
    ks = [trace[(:k,i)] for i=1:layers]
    
    for i=1:layers
        in_dim, out_dim = layer_unpacker(i, layers, ks)
        W = reshape(trace[(:W,i)], out_dim, in_dim)
        b = reshape(trace[(:b,i)], trace[(:k,i)])
        nn = Dense(W, b, activation)
        x = nn(x)
    end
    
    Wₒ = reshape(trace[(:W,layers+1)], c, ks[layers])
    bₒ = reshape(trace[(:b,layers+1)], c)
    
    nn_out = Dense(Wₒ, bₒ)
    x = nn_out(x)
    
    return softmax_(x)
end;

# %%
@gen function classifier(x)
    
    #Create a blank choicemap
    obs = choicemap()::ChoiceMap
    
    #Draw number of layers - 1 for Classifier Net
    l ~ categorical([1.0])
    l_real = l
    obs[:l] = l
    
    #Create individual weight and bias vectors
    #Loop through hidden layers
    k = [Int(0) for i=1:l+1]
    for i=1:l
        k[i] = @trace(categorical([1/length(k_list) for i=1:length(k_list)]), (:k,i))
        obs[(:k,i)] = k[i]
    end
    output_array = zeros(Float64, c)
    output_array[c] = 1.0

    k[l+1] = @trace(categorical(output_array), (:k,l+1))
    obs[(:k,l+1)] = k[l+1]
    
    ########################################
    #Fixed Hyperparameter schedule - Apr 26#
    ########################################
    
    σ = 1.0
    
    #Sample weight and bias vectors
    W = [zeros(k[i]) for i=1:l+1]
    b = [zeros(k[i]) for i=1:l+1]

    for i=1:l+1
        if i == 1
            h = Int(d * k[i])
        else
            h = Int(k[i-1] * k[i])
        end

        if i<=l
            #Hidden Weights
            u = zeros(h)
            S = Diagonal([σ for j=1:length(u)])
            W[i] = @trace(mvnormal(u,S), (:W,i))
            obs[(:W,i)] = W[i]
            
            #Hidden Biases
            ub = zeros(k[i])
            Sb = Diagonal([σ for j=1:length(ub)])   
            b[i] = @trace(mvnormal(ub,Sb), (:b,i))
            obs[(:b,i)] = b[i]
        else
            #Output Weights
            u = zeros(h)
            S = Diagonal([σ for j=1:length(u)])
            W[i] = @trace(mvnormal(u,S), (:W,i))
            obs[(:W,i)] = W[i]

            #Output Bias
            ub = zeros(c)
            Sb = Diagonal([σ for j=1:length(ub)]) 
            b[i] = @trace(mvnormal(ub,Sb), (:b,i))
            obs[(:b,i)] = b[i]
        end
    end
    
    #Return Network Scores for X
    scores = G(x,obs)
    
    #Logistic Classification Likelihood
    y = zeros(length(scores))
    for j=1:length(x[1,:])
        score_vec = scores[:,j]
        #println(score_vec)
        y[j] = @trace(categorical(score_vec), (:y,j))
    end
    
    return scores
    
end;

obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;

(best_trace,) = generate(classifier, (xt,), obs)
println(get_score(best_trace))
println(best_trace[(:k,1)])
test_labels = G(xt,best_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
# Out:
# -389.2809411855875
# 15
# 95

# %%
include("dockerxor/proposals.jl")
obs[(:k,1)] = 2
(best_trace,) = generate(classifier, (xt,), obs)
new_trace,q = node_birth(best_trace)
display(reshape(best_trace[(:W,1)], best_trace[(:k,1)], d))
display(reshape(new_trace[(:W,1)], new_trace[(:k,1)], d))
println(get_score(best_trace))
println(get_score(new_trace))

test_labels = G(xt,best_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("Old trace Accuracy: $test_acc")

test_labels = G(xt,new_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("New trace Accuracy: $test_acc")

println("q: $q")
# Out:
# 2×2 Array{Float64,2}:
#  -0.417073  -1.01292
#   0.689971  -0.816298
# 3×2 Array{Float64,2}:
#  -0.417073  -1.01292
#   0.866227   1.04446
#   0.689971  -0.816298
# -155.99771187079875
# -179.72280645897888
# Old trace Accuracy: 126
# New trace Accuracy: 136
# q: 4.94256434364851

# %%
include("dockerxor/proposals.jl")

println("Current k: $(best_trace[(:k,1)])")
new_trace2,q = node_death(new_trace)
display(reshape(new_trace[(:W,1)], new_trace[(:k,1)], d))
display(reshape(new_trace2[(:W,1)], new_trace2[(:k,1)], d))
println(get_score(new_trace))
println(get_score(new_trace2))

test_labels = G(xt,new_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("Old trace Accuracy: $test_acc")

test_labels = G(xt,new_trace2)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("New trace Accuracy: $test_acc")

println("q: $q")
# Out:
# 3×2 Array{Float64,2}:
#  -0.417073  -1.01292
#   0.866227   1.04446
#   0.689971  -0.816298
# 2×2 Array{Float64,2}:
#  0.866227   1.04446
#  0.689971  -0.816298
# Current k: 2
# -179.72280645897888
# -206.1303066034492
# Old trace Accuracy: 136
# New trace Accuracy: 119
# q: -5.69321551588061

# %%
#Test Likelihood
obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;

scores = []
accs = []
traces = []
ks = []
for i = 1:1000
    (trace,) = generate(classifier, (xt,), obs)
    push!(ks,trace[(:k,1)])
    push!(scores,get_score(trace))
    push!(traces,trace)
    test_labels = G(xt,trace)
    results = label_output(test_labels)
    test_acc = sum([y[i] == results[i] for i=1:length(y)])/length(y)
    test_acc = sum([euclidean(yt[:,j],test_labels[:,j]) for j=1:length(y)])
    push!(accs,test_acc)
end

scatter(accs,scores)
#plt.ylim(-2000,0)
#println(ks)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x7f0045869d90>

# %%
#-------------
#Run Inference
#-------------

include("dockerxor/NUTS.jl")
Δ_max = 1
acc_prob = 0.65
#Random.seed!(1)

scores = []
traces = []
ks = []
across_acceptance = []
within_acceptance = []

#Inference Hyperparameters
across_iters = 1
m = 1

function nuts_parameters(trace)
    
    l = trace[:l]
    param_selection = select()
    for i=1:l+1 #Number of Layers
        push!(param_selection, (:W,i))
        push!(param_selection, (:b,i))
    end
    
    prev_score = get_score(trace)
    
    acc = 0
    for i=1:1
        new_trace = NUTS(trace, param_selection, 0.65, m, m, false)[m+1]
        new_score = get_score(new_trace)
        if prev_score != new_score
            #println("Accepted")
            return (new_trace, 1)
        else
            return (trace, 0)
        end
    end
    
    return (trace, acc)
end

function node_parameter(trace)
    obs = obs_master
    
    init_trace = trace
    
    #################################################RJNUTS#################################################
    #NUTS Step 1
    trace_tilde = trace
    for i=1:across_iters
        (trace_tilde,) = nuts_parameters(trace_tilde)
    end
    
    #Reversible Jump Step
    (trace_prime, q_weight) = node_change(trace_tilde)
    
    #NUTS Step 2
    trace_star = trace_prime
    for i=1:across_iters
        (trace_star,) = nuts_parameters(trace_star)
    end
    #################################################RJNUTS#################################################
        
    model_score = -get_score(init_trace) + get_score(trace_star)
    across_score = model_score + q_weight

    if rand() < exp(across_score)
        println("********** Accepted: $(trace_star[(:k,1)]) **********")
        return (trace_star, 1)
    else
        return (init_trace, 0)
    end
end

obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;
obs[(:k,1)] = 1

(trace,) = generate(classifier, (xt,), obs)
#trace = best_trace
starting_k = trace[(:k,1)]
println("Starting k: $starting_k")
flush(stdout)
traces = []

for i=1:1000
    (trace, accepted) = node_parameter(trace)
    push!(across_acceptance, accepted)
    (trace, accepted) = nuts_parameters(trace)
    push!(within_acceptance, accepted)
    push!(scores,get_score(trace))
    push!(traces, trace)
    #println("$i : $(get_score(trace))")
    flush(stdout)
    if i%10 == 0
        a_acc = 100*(sum(across_acceptance)/length(across_acceptance))
        w_acc = 100*(sum(within_acceptance)/length(within_acceptance))
        println("Epoch $i A Acceptance Probability: $a_acc %")
        println("Epoch $i W Acceptance Probability: $w_acc %")
    end
end
# Out:
# Starting k: 1
# ********** Accepted: 2 **********
# ********** Accepted: 1 **********
# ********** Accepted: 2 **********
# ********** Accepted: 1 **********
# ********** Accepted: 2 **********
# Epoch 10 A Acceptance Probability: 50.0 %
# Epoch 10 W Acceptance Probability: 50.0 %
# ********** Accepted: 3 **********
# Epoch 20 A Acceptance Probability: 30.0 %
# Epoch 20 W Acceptance Probability: 60.0 %
# ********** Accepted: 4 **********
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# Epoch 30 A Acceptance Probability: 30.0 %
# Epoch 30 W Acceptance Probability: 63.33333333333333 %
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# ********** Accepted: 8 **********
# Epoch 40 A Acceptance Probability: 32.5 %
# Epoch 40 W Acceptance Probability: 60.0 %
# Epoch 50 A Acceptance Probability: 26.0 %
# Epoch 50 W Acceptance Probability: 60.0 %
# ********** Accepted: 7 **********
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# ********** Accepted: 8 **********
# Epoch 60 A Acceptance Probability: 28.333333333333332 %
# Epoch 60 W Acceptance Probability: 60.0 %
# Epoch 70 A Acceptance Probability: 24.285714285714285 %
# Epoch 70 W Acceptance Probability: 62.857142857142854 %
# Epoch 80 A Acceptance Probability: 21.25 %
# Epoch 80 W Acceptance Probability: 63.74999999999999 %
# ********** Accepted: 9 **********
# Epoch 90 A Acceptance Probability: 20.0 %
# Epoch 90 W Acceptance Probability: 64.44444444444444 %
# ********** Accepted: 10 **********
# Epoch 100 A Acceptance Probability: 19.0 %
# Epoch 100 W Acceptance Probability: 64.0 %
# ********** Accepted: 11 **********
# ********** Accepted: 10 **********
# ********** Accepted: 11 **********
# Epoch 110 A Acceptance Probability: 20.0 %
# Epoch 110 W Acceptance Probability: 63.63636363636363 %
# ********** Accepted: 10 **********
# Epoch 120 A Acceptance Probability: 19.166666666666668 %
# Epoch 120 W Acceptance Probability: 62.5 %
# ********** Accepted: 9 **********
# ********** Accepted: 10 **********
# ********** Accepted: 9 **********
# ********** Accepted: 8 **********
# Epoch 130 A Acceptance Probability: 20.76923076923077 %
# Epoch 130 W Acceptance Probability: 63.07692307692307 %
# ********** Accepted: 7 **********
# Epoch 140 A Acceptance Probability: 20.0 %
# Epoch 140 W Acceptance Probability: 63.57142857142857 %
# Epoch 150 A Acceptance Probability: 18.666666666666668 %
# Epoch 150 W Acceptance Probability: 62.0 %
# Epoch 160 A Acceptance Probability: 17.5 %
# Epoch 160 W Acceptance Probability: 63.74999999999999 %
# Epoch 170 A Acceptance Probability: 16.470588235294116 %
# Epoch 170 W Acceptance Probability: 62.94117647058823 %
# Epoch 180 A Acceptance Probability: 15.555555555555555 %
# Epoch 180 W Acceptance Probability: 62.77777777777778 %
# Epoch 190 A Acceptance Probability: 14.736842105263156 %
# Epoch 190 W Acceptance Probability: 64.21052631578948 %
# ********** Accepted: 8 **********
# Epoch 200 A Acceptance Probability: 14.499999999999998 %
# Epoch 200 W Acceptance Probability: 64.0 %
# ********** Accepted: 9 **********
# Epoch 210 A Acceptance Probability: 14.285714285714285 %
# Epoch 210 W Acceptance Probability: 62.857142857142854 %
# ********** Accepted: 10 **********
# ********** Accepted: 11 **********
# Epoch 220 A Acceptance Probability: 14.545454545454545 %
# Epoch 220 W Acceptance Probability: 62.727272727272734 %
# Epoch 230 A Acceptance Probability: 13.91304347826087 %
# Epoch 230 W Acceptance Probability: 63.04347826086957 %
# Epoch 240 A Acceptance Probability: 13.333333333333334 %
# Epoch 240 W Acceptance Probability: 62.5 %
# Epoch 250 A Acceptance Probability: 12.8 %
# Epoch 250 W Acceptance Probability: 63.2 %
# Epoch 260 A Acceptance Probability: 12.307692307692308 %
# Epoch 260 W Acceptance Probability: 63.07692307692307 %
# ********** Accepted: 10 **********
# ********** Accepted: 9 **********
# Epoch 270 A Acceptance Probability: 12.592592592592592 %
# Epoch 270 W Acceptance Probability: 62.59259259259259 %
# ********** Accepted: 10 **********
# Epoch 280 A Acceptance Probability: 12.5 %
# Epoch 280 W Acceptance Probability: 63.57142857142857 %
# ********** Accepted: 11 **********
# ********** Accepted: 10 **********
# Epoch 290 A Acceptance Probability: 12.758620689655173 %
# Epoch 290 W Acceptance Probability: 63.793103448275865 %
# Epoch 300 A Acceptance Probability: 12.333333333333334 %
# Epoch 300 W Acceptance Probability: 64.33333333333333 %
# ********** Accepted: 9 **********
# Epoch 310 A Acceptance Probability: 12.258064516129032 %
# Epoch 310 W Acceptance Probability: 64.83870967741936 %
# Epoch 320 A Acceptance Probability: 11.875 %
# Epoch 320 W Acceptance Probability: 65.625 %
# Epoch 330 A Acceptance Probability: 11.515151515151516 %
# Epoch 330 W Acceptance Probability: 65.45454545454545 %
# ********** Accepted: 8 **********
# Epoch 340 A Acceptance Probability: 11.470588235294118 %
# Epoch 340 W Acceptance Probability: 65.0 %
# ********** Accepted: 9 **********
# ********** Accepted: 10 **********
# ********** Accepted: 9 **********
# Epoch 350 A Acceptance Probability: 12.0 %
# Epoch 350 W Acceptance Probability: 65.42857142857143 %
# Epoch 360 A Acceptance Probability: 11.666666666666666 %
# Epoch 360 W Acceptance Probability: 65.27777777777779 %
# ********** Accepted: 8 **********
# Epoch 370 A Acceptance Probability: 11.621621621621623 %
# Epoch 370 W Acceptance Probability: 65.13513513513513 %
# ********** Accepted: 9 **********
# Epoch 380 A Acceptance Probability: 11.578947368421053 %
# Epoch 380 W Acceptance Probability: 65.52631578947368 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# Epoch 390 A Acceptance Probability: 11.794871794871794 %
# Epoch 390 W Acceptance Probability: 65.38461538461539 %
# Epoch 400 A Acceptance Probability: 11.5 %
# Epoch 400 W Acceptance Probability: 65.25 %
# Epoch 410 A Acceptance Probability: 11.219512195121952 %
# Epoch 410 W Acceptance Probability: 65.85365853658537 %
# Epoch 420 A Acceptance Probability: 10.952380952380953 %
# Epoch 420 W Acceptance Probability: 65.71428571428571 %
# Epoch 430 A Acceptance Probability: 10.69767441860465 %
# Epoch 430 W Acceptance Probability: 65.11627906976744 %
# Epoch 440 A Acceptance Probability: 10.454545454545453 %
# Epoch 440 W Acceptance Probability: 64.77272727272727 %
# ********** Accepted: 6 **********
# Epoch 450 A Acceptance Probability: 10.444444444444445 %
# Epoch 450 W Acceptance Probability: 64.88888888888889 %
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# Epoch 460 A Acceptance Probability: 10.652173913043478 %
# Epoch 460 W Acceptance Probability: 65.21739130434783 %
# Epoch 470 A Acceptance Probability: 10.425531914893616 %
# Epoch 470 W Acceptance Probability: 65.74468085106383 %
# Epoch 480 A Acceptance Probability: 10.208333333333334 %
# Epoch 480 W Acceptance Probability: 66.04166666666667 %
# Epoch 490 A Acceptance Probability: 10.0 %
# Epoch 490 W Acceptance Probability: 65.51020408163265 %
# Epoch 500 A Acceptance Probability: 9.8 %
# Epoch 500 W Acceptance Probability: 65.2 %
# Epoch 510 A Acceptance Probability: 9.607843137254903 %
# Epoch 510 W Acceptance Probability: 64.70588235294117 %
# Epoch 520 A Acceptance Probability: 9.423076923076923 %
# Epoch 520 W Acceptance Probability: 65.1923076923077 %
# ********** Accepted: 7 **********
# Epoch 530 A Acceptance Probability: 9.433962264150944 %
# Epoch 530 W Acceptance Probability: 65.28301886792453 %
# ********** Accepted: 6 **********
# Epoch 540 A Acceptance Probability: 9.444444444444445 %
# Epoch 540 W Acceptance Probability: 65.55555555555556 %
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# Epoch 550 A Acceptance Probability: 9.636363636363637 %
# Epoch 550 W Acceptance Probability: 66.18181818181819 %
# Epoch 560 A Acceptance Probability: 9.464285714285714 %
# Epoch 560 W Acceptance Probability: 66.25 %
# Epoch 570 A Acceptance Probability: 9.298245614035087 %
# Epoch 570 W Acceptance Probability: 65.78947368421053 %
# Epoch 580 A Acceptance Probability: 9.137931034482758 %
# Epoch 580 W Acceptance Probability: 65.86206896551724 %
# ********** Accepted: 7 **********
# Epoch 590 A Acceptance Probability: 9.152542372881356 %
# Epoch 590 W Acceptance Probability: 65.93220338983052 %
# ********** Accepted: 8 **********
# Epoch 600 A Acceptance Probability: 9.166666666666666 %
# Epoch 600 W Acceptance Probability: 66.16666666666666 %
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# Epoch 610 A Acceptance Probability: 9.508196721311474 %
# Epoch 610 W Acceptance Probability: 66.22950819672131 %
# Epoch 620 A Acceptance Probability: 9.35483870967742 %
# Epoch 620 W Acceptance Probability: 65.96774193548387 %
# Epoch 630 A Acceptance Probability: 9.206349206349207 %
# Epoch 630 W Acceptance Probability: 66.03174603174602 %
# ********** Accepted: 6 **********
# Epoch 640 A Acceptance Probability: 9.21875 %
# Epoch 640 W Acceptance Probability: 65.9375 %
# ********** Accepted: 7 **********
# Epoch 650 A Acceptance Probability: 9.230769230769232 %
# Epoch 650 W Acceptance Probability: 65.6923076923077 %
# Epoch 660 A Acceptance Probability: 9.090909090909092 %
# Epoch 660 W Acceptance Probability: 66.06060606060606 %
# Epoch 670 A Acceptance Probability: 8.955223880597014 %
# Epoch 670 W Acceptance Probability: 65.97014925373135 %
# Epoch 680 A Acceptance Probability: 8.823529411764707 %
# Epoch 680 W Acceptance Probability: 66.47058823529412 %
# Epoch 690 A Acceptance Probability: 8.695652173913043 %
# Epoch 690 W Acceptance Probability: 66.23188405797102 %
# Epoch 700 A Acceptance Probability: 8.571428571428571 %
# Epoch 700 W Acceptance Probability: 66.14285714285715 %
# Epoch 710 A Acceptance Probability: 8.450704225352112 %
# Epoch 710 W Acceptance Probability: 66.61971830985915 %
# Epoch 720 A Acceptance Probability: 8.333333333333332 %
# Epoch 720 W Acceptance Probability: 66.94444444444444 %
# Epoch 730 A Acceptance Probability: 8.21917808219178 %
# Epoch 730 W Acceptance Probability: 66.84931506849315 %
# Epoch 740 A Acceptance Probability: 8.108108108108109 %
# Epoch 740 W Acceptance Probability: 67.16216216216216 %
# Epoch 750 A Acceptance Probability: 8.0 %
# Epoch 750 W Acceptance Probability: 67.46666666666667 %
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 760 A Acceptance Probability: 8.157894736842106 %
# Epoch 760 W Acceptance Probability: 67.36842105263158 %
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 770 A Acceptance Probability: 8.311688311688311 %
# Epoch 770 W Acceptance Probability: 67.66233766233766 %
# ********** Accepted: 6 **********
# Epoch 780 A Acceptance Probability: 8.333333333333332 %
# Epoch 780 W Acceptance Probability: 67.43589743589745 %
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# Epoch 790 A Acceptance Probability: 8.481012658227847 %
# Epoch 790 W Acceptance Probability: 67.46835443037975 %
# ********** Accepted: 7 **********
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# Epoch 800 A Acceptance Probability: 8.75 %
# Epoch 800 W Acceptance Probability: 67.5 %
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# Epoch 810 A Acceptance Probability: 8.88888888888889 %
# Epoch 810 W Acceptance Probability: 67.53086419753086 %
# Epoch 820 A Acceptance Probability: 8.780487804878048 %
# Epoch 820 W Acceptance Probability: 67.4390243902439 %
# Epoch 830 A Acceptance Probability: 8.674698795180722 %
# Epoch 830 W Acceptance Probability: 67.34939759036145 %
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# Epoch 840 A Acceptance Probability: 8.80952380952381 %
# Epoch 840 W Acceptance Probability: 67.26190476190477 %
# Epoch 850 A Acceptance Probability: 8.705882352941176 %
# Epoch 850 W Acceptance Probability: 67.52941176470588 %
# ********** Accepted: 6 **********
# Epoch 860 A Acceptance Probability: 8.720930232558139 %
# Epoch 860 W Acceptance Probability: 67.44186046511628 %
# ********** Accepted: 5 **********
# Epoch 870 A Acceptance Probability: 8.735632183908045 %
# Epoch 870 W Acceptance Probability: 67.58620689655173 %
# Epoch 880 A Acceptance Probability: 8.636363636363637 %
# Epoch 880 W Acceptance Probability: 67.8409090909091 %
# ********** Accepted: 6 **********
# Epoch 890 A Acceptance Probability: 8.651685393258427 %
# Epoch 890 W Acceptance Probability: 68.08988764044945 %
# ********** Accepted: 7 **********
# Epoch 900 A Acceptance Probability: 8.666666666666668 %
# Epoch 900 W Acceptance Probability: 68.22222222222221 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# Epoch 910 A Acceptance Probability: 8.791208791208792 %
# Epoch 910 W Acceptance Probability: 68.02197802197803 %
# ********** Accepted: 6 **********
# Epoch 920 A Acceptance Probability: 8.804347826086957 %
# Epoch 920 W Acceptance Probability: 68.15217391304348 %
# ********** Accepted: 5 **********
# Epoch 930 A Acceptance Probability: 8.817204301075268 %
# Epoch 930 W Acceptance Probability: 67.95698924731182 %
# Epoch 940 A Acceptance Probability: 8.72340425531915 %
# Epoch 940 W Acceptance Probability: 68.08510638297872 %
# Epoch 950 A Acceptance Probability: 8.631578947368421 %
# Epoch 950 W Acceptance Probability: 68.21052631578948 %
# ********** Accepted: 4 **********
# Epoch 960 A Acceptance Probability: 8.645833333333334 %
# Epoch 960 W Acceptance Probability: 68.125 %
# ********** Accepted: 5 **********
# Epoch 970 A Acceptance Probability: 8.65979381443299 %
# Epoch 970 W Acceptance Probability: 68.24742268041237 %
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# Epoch 980 A Acceptance Probability: 8.775510204081632 %
# Epoch 980 W Acceptance Probability: 68.46938775510203 %
# ********** Accepted: 4 **********
# Epoch 990 A Acceptance Probability: 8.787878787878787 %
# Epoch 990 W Acceptance Probability: 68.58585858585859 %
# ********** Accepted: 5 **********
# Epoch 1000 A Acceptance Probability: 8.799999999999999 %
# Epoch 1000 W Acceptance Probability: 68.60000000000001 %

# %%
#Log Posterior Score Chart
obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;

plot([get_score(trace) for trace in traces])
plt.title("NUTS Score: MNIST Classification")
plt.xlabel("Iteration")
plt.ylabel("Log Posterior");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Node Count Histogram

########################
#Bar Plot of l estimates
########################

ks = [traces[i][(:k,1)] for i in 1:length(traces)]
counts = [sum([ks[i] == j for i in 1:length(ks)]) for j in k_list]

barlist=bar(k_list,counts)
for i in 1:k_range
    barlist[i].set_color([0.8,0.0,0.0])
end
#barlist[2].set_color([0.0,0.8,0.1])

plt.title("MNIST Classification: Number of Hidden Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Frequency");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Node Count Chart

plot([trace[(:k,1)] for trace in traces])
plt.title("MNIST Classification: Number of Hidden Nodes")
plt.xlabel("Iteration")
plt.ylabel("Node Count");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Plot Training Accuracy
accs = []
accs2 = []
dists = []
dists2 = []
for i = 1:length(traces)
    trace = traces[i]
    test_labels = G(xt,trace)
    results = label_output(test_labels)
    test_acc = sum([y[i] == results[i] for i=1:length(y)])/length(y)
    test_dist = sum([euclidean(yt[:,j],test_labels[:,j]) for j=1:length(y)])
    push!(accs,test_acc)
    push!(dists,test_dist)
    
    trace = traces[i]
    test_labels = G(xt_test,trace)
    results = label_output(test_labels)
    test_acc = sum([y_test[i] == results[i] for i=1:length(y_test)])/length(y_test)
    test_dist = sum([euclidean(yzt[:,j],test_labels[:,j]) for j=1:length(y)])
    push!(accs2,test_acc)
    push!(dists2,test_dist)
end

plot(accs,label="Train")
plot(accs2,label="Test",c="lightgreen")
plt.title("NUTS Accuracy: MNIST Classification Accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plot(dists,label="Train")
plot(dists2,label="Test",color="lightgreen")
plt.title("NUTS Euclidean Distance")
plt.xlabel("Iteration")
plt.ylabel("Euclidean Distance")
plt.legend();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Marginalize Probabilities - Train Set
j = 200
targets = zeros(length(traces)-j,c,N)
for i=j:length(traces)-j
    trace = traces[i]
    labels = G(xt,trace)
    targets[i-j+1,:,:] = labels
end

sums = sum(targets,dims=1)[1,:,:]./(length(traces)-j)
guesses = [findmax(sums[:,i])[2] for i=1:N]
test_acc = sum([y[i] == guesses[i] for i=1:length(y)])
# Out:
# 179

# %%
#Marginalize Probabilities - Test Set
j = 200
targets = zeros(length(traces)-j,c,N)
for i=j:length(traces)-j
    trace = traces[i]
    labels = G(xt_test,trace)
    targets[i-j+1,:,:] = labels
end

sums = sum(targets,dims=1)[1,:,:]./(length(traces)-j)
guesses = [findmax(sums[:,i])[2] for i=1:N]
test_acc = sum([yz[i] == guesses[i] for i=1:length(yz)])
# Out:
# 180

# %%
function plot_grid(data,scores,alpha=1.0)
    PyPlot.scatter(data[:,1],data[:,2],c=scores,alpha=alpha,cmap="PRGn")
    #PyPlot.colorbar()
end

function tracegrid(traces, samples=800, low=-3.0, high=3.0)
    d=2
    n=100
    starting_iter = 200
    r = range(low, high, length = n)
    
    iter = Iterators.product((r for _ in 1:d)...)
    grid= vec([collect(i) for i in iter])
    grid_raw = reduce(hcat, getindex.(grid,i) for i in eachindex(grid[1]))
    grid2 = transpose(grid_raw)
    z_master = zeros(length(grid2[1,:]))
    
    for i=1:samples
        j = rand((starting_iter,length(traces)))
        trace = traces[j]
        z = G(grid2,trace)[1,:]
        #display(z)
        z_master += (z ./ samples)
    end
    plot_grid(grid_raw, z_master)
end

tracegrid(traces)
plot_data_classifier(x_raw,classes)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
weights = [trace[(:W,1)][1] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][2] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][3] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][48] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][57] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][58] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][59] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][60] for trace in traces]
plot(weights)
# Out:
# BoundsError: attempt to access 2-element Array{Float64,1} at index [3]
#
# Stacktrace:
#  [1] getindex(::Array{Float64,1}, ::Int64) at ./array.jl:788
#  [2] (::var"#1822#1823")(::Gen.DynamicDSLTrace{DynamicDSLFunction{Any}}) at ./none:0
#  [3] iterate at ./generator.jl:47 [inlined]
#  [4] collect(::Base.Generator{Array{Any,1},var"#1822#1823"}) at ./array.jl:665
#  [5] top-level scope at In[213]:5

# %%
plot([1/trace[(:τᵦ,2)] for trace in traces])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb219dfa150>
