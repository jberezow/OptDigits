# %%
#Classification of XOR dataset 
using Gen
using PyPlot
using Distributions
using LinearAlgebra
using Random
using Distances
using Flux
using StatsBase
using MultivariateStats
using MLDatasets

include("dockerxor/proposals.jl")
include("dockerxor/utils.jl");

# %%
#------------------------------------
#Hyperparameters and Helper Functions
#------------------------------------

#Select Network Goal
network = "classifier"

#Data hyperparameters
c = 2
n = 50 #Number of samples per mode (classifier)
m = 4 #Number of modes (classifier)
d = 2 #Input dimension
N = n*m #Total samples
σₐ = 0.1 #Mode variance (classifier)
bound = 0.5

#Node hyperparameters
k_range = 16 #Maximum number of neurons per layer
k_list = [Int(i) for i in 1:k_range]

#NUTS
Δ_max = 1000;

x_raw, classes = real_data_classifier(Int(N/4), 4, bound, σₐ);
classes = [(i+1) % 2 + 1 for i in classes]
y = classes

plot_data_classifier(x_raw,classes)
xt = transpose(x_raw)
size(xt)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (2, 200)

# %%
#One-Hot Encode Y
yt = Flux.onehotbatch(y,[:1,:2]);

#Test Set
x_raw_test, classes_test = real_data_classifier(Int(N/4), 4, bound, σₐ);
xt_test = transpose(x_raw_test)
classes_test = [(i+1) % 2 + 1 for i in classes]
y_test = classes_test
yz = y_test
yzt = Flux.onehotbatch(yz,[:1,:2]);

# %%
function softmax_(arr::AbstractArray)
    ex = mapslices(x -> exp.(0.5.*x),arr,dims=1)
    rows, cols = size(arr)
    val = similar(ex)
    for i in 1:cols
        s = sum(ex[:,i])
        for j in 1:rows
            val[j,i] = ex[j,i]/s
        end
    end
    return val
end;

#Bayesian Neural Net
function G(x, trace)
    activation = tanh
    layers = trace[:l]
    ks = [trace[(:k,i)] for i=1:layers]
    
    for i=1:layers
        in_dim, out_dim = layer_unpacker(i, layers, ks)
        W = reshape(trace[(:W,i)], out_dim, in_dim)
        b = reshape(trace[(:b,i)], trace[(:k,i)])
        nn = Dense(W, b, activation)
        x = nn(x)
    end
    
    Wₒ = reshape(trace[(:W,layers+1)], c, ks[layers])
    bₒ = reshape(trace[(:b,layers+1)], c)
    
    nn_out = Dense(Wₒ, bₒ)
    x = nn_out(x)
    
    return softmax_(x)
end;

# %%
@gen function classifier(x)
    
    #Create a blank choicemap
    obs = choicemap()::ChoiceMap
    
    #Draw number of layers - 1 for Classifier Net
    l ~ categorical([1.0])
    l_real = l
    obs[:l] = l
    
    #Create individual weight and bias vectors
    #Loop through hidden layers
    k = [Int(0) for i=1:l+1]
    for i=1:l
        k[i] = @trace(categorical([1/length(k_list) for i=1:length(k_list)]), (:k,i))
        obs[(:k,i)] = k[i]
    end
    output_array = zeros(Float64, c)
    output_array[c] = 1.0

    k[l+1] = @trace(categorical(output_array), (:k,l+1))
    obs[(:k,l+1)] = k[l+1]
    
    ########################################
    #Fixed Hyperparameter schedule - Apr 26#
    ########################################
    
    σ = 1.0
    
    #Sample weight and bias vectors
    W = [zeros(k[i]) for i=1:l+1]
    b = [zeros(k[i]) for i=1:l+1]

    for i=1:l+1
        if i == 1
            h = Int(d * k[i])
        else
            h = Int(k[i-1] * k[i])
        end

        if i<=l
            #Hidden Weights
            u = zeros(h)
            S = Diagonal([σ for j=1:length(u)])
            W[i] = @trace(mvnormal(u,S), (:W,i))
            obs[(:W,i)] = W[i]
            
            #Hidden Biases
            ub = zeros(k[i])
            Sb = Diagonal([σ for j=1:length(ub)])   
            b[i] = @trace(mvnormal(ub,Sb), (:b,i))
            obs[(:b,i)] = b[i]
        else
            #Output Weights
            u = zeros(h)
            S = Diagonal([σ for j=1:length(u)])
            W[i] = @trace(mvnormal(u,S), (:W,i))
            obs[(:W,i)] = W[i]

            #Output Bias
            ub = zeros(c)
            Sb = Diagonal([σ for j=1:length(ub)]) 
            b[i] = @trace(mvnormal(ub,Sb), (:b,i))
            obs[(:b,i)] = b[i]
        end
    end
    
    #Return Network Scores for X
    scores = G(x,obs)
    
    #Logistic Classification Likelihood
    y = zeros(length(scores))
    for j=1:length(x[1,:])
        score_vec = scores[:,j]
        #println(score_vec)
        y[j] = @trace(categorical(score_vec), (:y,j))
    end
    
    return scores
    
end;

obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;

(best_trace,) = generate(classifier, (xt,), obs)
println(get_score(best_trace))
println(best_trace[(:k,1)])
test_labels = G(xt,best_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
# Out:
# -182.0040809065031
# 3
# 75

# %%
include("dockerxor/proposals.jl")
obs[(:k,1)] = 2
(best_trace,) = generate(classifier, (xt,), obs)
new_trace,q = node_birth(best_trace)
display(reshape(best_trace[(:W,1)], best_trace[(:k,1)], d))
display(reshape(new_trace[(:W,1)], new_trace[(:k,1)], d))
println(get_score(best_trace))
println(get_score(new_trace))

test_labels = G(xt,best_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("Old trace Accuracy: $test_acc")

test_labels = G(xt,new_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("New trace Accuracy: $test_acc")

println("q: $q")
# Out:
# 2×2 Array{Float64,2}:
#   2.34761    1.0903
#  -0.693075  -0.925339
# 3×2 Array{Float64,2}:
#   2.34761    1.0903
#  -0.693075  -0.925339
#   0.57719    1.21385
# -175.10830152266658
# -187.98015581754788
# Old trace Accuracy: 82
# New trace Accuracy: 104
# q: 6.625517404656514

# %%
include("dockerxor/proposals.jl")

println("Current k: $(best_trace[(:k,1)])")
new_trace2,q = node_death(new_trace)
display(reshape(new_trace[(:W,1)], new_trace[(:k,1)], d))
display(reshape(new_trace2[(:W,1)], new_trace2[(:k,1)], d))
println(get_score(new_trace))
println(get_score(new_trace2))

test_labels = G(xt,new_trace)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("Old trace Accuracy: $test_acc")

test_labels = G(xt,new_trace2)
results = label_output(test_labels)
test_acc = sum([y[i] == results[i] for i=1:length(y)])
println("New trace Accuracy: $test_acc")

println("q: $q")
# Out:
# 3×2 Array{Float64,2}:
#   2.34761    1.0903
#  -0.693075  -0.925339
#   0.57719    1.21385
# 2×2 Array{Float64,2}:
#   2.34761    1.0903
#  -0.693075  -0.925339
# Current k: 2
# -187.98015581754788
# -175.10830152266658
# Old trace Accuracy: 104
# New trace Accuracy: 82
# q: -7.724129693324624

# %%
#Test Likelihood
obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;

scores = []
accs = []
traces = []
ks = []
for i = 1:1000
    (trace,) = generate(classifier, (xt,), obs)
    push!(ks,trace[(:k,1)])
    push!(scores,get_score(trace))
    push!(traces,trace)
    test_labels = G(xt,trace)
    results = label_output(test_labels)
    test_acc = sum([y[i] == results[i] for i=1:length(y)])/length(y)
    test_acc = sum([euclidean(yt[:,j],test_labels[:,j]) for j=1:length(y)])
    push!(accs,test_acc)
end

scatter(accs,scores)
#plt.ylim(-2000,0)
#println(ks)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x7efbe5c27e10>

# %%
#-------------
#Run Inference
#-------------

include("dockerxor/NUTS.jl")
Δ_max = 1
acc_prob = 0.65
#Random.seed!(1)

scores = []
traces = []
ks = []
across_acceptance = []
within_acceptance = []

#Inference Hyperparameters
across_iters = 1
m = 1

function nuts_parameters(trace)
    
    l = trace[:l]
    param_selection = select()
    for i=1:l+1 #Number of Layers
        push!(param_selection, (:W,i))
        push!(param_selection, (:b,i))
    end
    
    prev_score = get_score(trace)
    
    acc = 0
    for i=1:1
        new_trace = NUTS(trace, param_selection, 0.65, m, m, false)[m+1]
        new_score = get_score(new_trace)
        if prev_score != new_score
            #println("Accepted")
            return (new_trace, 1)
        else
            return (trace, 0)
        end
    end
    
    return (trace, acc)
end

function node_parameter(trace)
    obs = obs_master
    
    init_trace = trace
    
    #################################################RJNUTS#################################################
    #NUTS Step 1
    trace_tilde = trace
    for i=1:across_iters
        (trace_tilde,) = nuts_parameters(trace_tilde)
    end
    
    #Reversible Jump Step
    (trace_prime, q_weight) = node_change(trace_tilde)
    
    #NUTS Step 2
    trace_star = trace_prime
    for i=1:across_iters
        (trace_star,) = nuts_parameters(trace_star)
    end
    #################################################RJNUTS#################################################
        
    model_score = -get_score(init_trace) + get_score(trace_star)
    across_score = model_score + q_weight

    if rand() < exp(across_score)
        println("********** Accepted: $(trace_star[(:k,1)]) **********")
        return (trace_star, 1)
    else
        return (init_trace, 0)
    end
end

obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;
obs[(:k,1)] = 1

(trace,) = generate(classifier, (xt,), obs)
#trace = best_trace
starting_k = trace[(:k,1)]
println("Starting k: $starting_k")
flush(stdout)
traces = []

for i=1:1000
    (trace, accepted) = node_parameter(trace)
    push!(across_acceptance, accepted)
    (trace, accepted) = nuts_parameters(trace)
    push!(within_acceptance, accepted)
    push!(scores,get_score(trace))
    push!(traces, trace)
    #println("$i : $(get_score(trace))")
    flush(stdout)
    if i%10 == 0
        a_acc = 100*(sum(across_acceptance)/length(across_acceptance))
        w_acc = 100*(sum(within_acceptance)/length(within_acceptance))
        println("Epoch $i A Acceptance Probability: $a_acc %")
        println("Epoch $i W Acceptance Probability: $w_acc %")
    end
end
# Out:
# Starting k: 1
# ********** Accepted: 2 **********
# ********** Accepted: 1 **********
# ********** Accepted: 2 **********
# Epoch 10 A Acceptance Probability: 30.0 %
# Epoch 10 W Acceptance Probability: 60.0 %
# ********** Accepted: 1 **********
# Epoch 20 A Acceptance Probability: 20.0 %
# Epoch 20 W Acceptance Probability: 65.0 %
# ********** Accepted: 2 **********
# ********** Accepted: 1 **********
# ********** Accepted: 2 **********
# Epoch 30 A Acceptance Probability: 23.333333333333332 %
# Epoch 30 W Acceptance Probability: 56.666666666666664 %
# Epoch 40 A Acceptance Probability: 17.5 %
# Epoch 40 W Acceptance Probability: 62.5 %
# ********** Accepted: 3 **********
# ********** Accepted: 4 **********
# ********** Accepted: 5 **********
# ********** Accepted: 4 **********
# Epoch 50 A Acceptance Probability: 22.0 %
# Epoch 50 W Acceptance Probability: 64.0 %
# ********** Accepted: 5 **********
# ********** Accepted: 4 **********
# ********** Accepted: 3 **********
# Epoch 60 A Acceptance Probability: 23.333333333333332 %
# Epoch 60 W Acceptance Probability: 61.66666666666667 %
# Epoch 70 A Acceptance Probability: 20.0 %
# Epoch 70 W Acceptance Probability: 58.57142857142858 %
# ********** Accepted: 4 **********
# Epoch 80 A Acceptance Probability: 18.75 %
# Epoch 80 W Acceptance Probability: 57.49999999999999 %
# ********** Accepted: 5 **********
# Epoch 90 A Acceptance Probability: 17.77777777777778 %
# Epoch 90 W Acceptance Probability: 60.0 %
# Epoch 100 A Acceptance Probability: 16.0 %
# Epoch 100 W Acceptance Probability: 60.0 %
# Epoch 110 A Acceptance Probability: 14.545454545454545 %
# Epoch 110 W Acceptance Probability: 60.0 %
# Epoch 120 A Acceptance Probability: 13.333333333333334 %
# Epoch 120 W Acceptance Probability: 62.5 %
# ********** Accepted: 4 **********
# Epoch 130 A Acceptance Probability: 13.076923076923078 %
# Epoch 130 W Acceptance Probability: 61.53846153846154 %
# ********** Accepted: 5 **********
# Epoch 140 A Acceptance Probability: 12.857142857142856 %
# Epoch 140 W Acceptance Probability: 62.857142857142854 %
# Epoch 150 A Acceptance Probability: 12.0 %
# Epoch 150 W Acceptance Probability: 62.66666666666667 %
# Epoch 160 A Acceptance Probability: 11.25 %
# Epoch 160 W Acceptance Probability: 63.125 %
# ********** Accepted: 6 **********
# Epoch 170 A Acceptance Probability: 11.176470588235295 %
# Epoch 170 W Acceptance Probability: 62.94117647058823 %
# Epoch 180 A Acceptance Probability: 10.555555555555555 %
# Epoch 180 W Acceptance Probability: 63.33333333333333 %
# ********** Accepted: 7 **********
# Epoch 190 A Acceptance Probability: 10.526315789473683 %
# Epoch 190 W Acceptance Probability: 63.68421052631579 %
# Epoch 200 A Acceptance Probability: 10.0 %
# Epoch 200 W Acceptance Probability: 64.0 %
# ********** Accepted: 6 **********
# Epoch 210 A Acceptance Probability: 10.0 %
# Epoch 210 W Acceptance Probability: 62.857142857142854 %
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 220 A Acceptance Probability: 10.909090909090908 %
# Epoch 220 W Acceptance Probability: 63.18181818181819 %
# ********** Accepted: 6 **********
# Epoch 230 A Acceptance Probability: 10.869565217391305 %
# Epoch 230 W Acceptance Probability: 63.04347826086957 %
# Epoch 240 A Acceptance Probability: 10.416666666666668 %
# Epoch 240 W Acceptance Probability: 63.33333333333333 %
# Epoch 250 A Acceptance Probability: 10.0 %
# Epoch 250 W Acceptance Probability: 63.6 %
# ********** Accepted: 7 **********
# Epoch 260 A Acceptance Probability: 10.0 %
# Epoch 260 W Acceptance Probability: 63.46153846153846 %
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# Epoch 270 A Acceptance Probability: 10.74074074074074 %
# Epoch 270 W Acceptance Probability: 64.07407407407408 %
# Epoch 280 A Acceptance Probability: 10.357142857142858 %
# Epoch 280 W Acceptance Probability: 64.28571428571429 %
# Epoch 290 A Acceptance Probability: 10.0 %
# Epoch 290 W Acceptance Probability: 65.17241379310344 %
# Epoch 300 A Acceptance Probability: 9.666666666666666 %
# Epoch 300 W Acceptance Probability: 64.66666666666666 %
# Epoch 310 A Acceptance Probability: 9.35483870967742 %
# Epoch 310 W Acceptance Probability: 63.87096774193548 %
# ********** Accepted: 7 **********
# Epoch 320 A Acceptance Probability: 9.375 %
# Epoch 320 W Acceptance Probability: 63.74999999999999 %
# ********** Accepted: 6 **********
# Epoch 330 A Acceptance Probability: 9.393939393939393 %
# Epoch 330 W Acceptance Probability: 64.24242424242425 %
# Epoch 340 A Acceptance Probability: 9.117647058823529 %
# Epoch 340 W Acceptance Probability: 64.11764705882354 %
# Epoch 350 A Acceptance Probability: 8.857142857142856 %
# Epoch 350 W Acceptance Probability: 64.57142857142857 %
# ********** Accepted: 7 **********
# Epoch 360 A Acceptance Probability: 8.88888888888889 %
# Epoch 360 W Acceptance Probability: 65.0 %
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# Epoch 370 A Acceptance Probability: 9.45945945945946 %
# Epoch 370 W Acceptance Probability: 65.13513513513513 %
# ********** Accepted: 5 **********
# Epoch 380 A Acceptance Probability: 9.473684210526317 %
# Epoch 380 W Acceptance Probability: 65.52631578947368 %
# ********** Accepted: 6 **********
# Epoch 390 A Acceptance Probability: 9.487179487179487 %
# Epoch 390 W Acceptance Probability: 64.87179487179488 %
# Epoch 400 A Acceptance Probability: 9.25 %
# Epoch 400 W Acceptance Probability: 65.5 %
# ********** Accepted: 7 **********
# Epoch 410 A Acceptance Probability: 9.268292682926829 %
# Epoch 410 W Acceptance Probability: 65.3658536585366 %
# ********** Accepted: 8 **********
# Epoch 420 A Acceptance Probability: 9.285714285714286 %
# Epoch 420 W Acceptance Probability: 65.0 %
# ********** Accepted: 7 **********
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# Epoch 430 A Acceptance Probability: 10.0 %
# Epoch 430 W Acceptance Probability: 65.58139534883722 %
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# Epoch 440 A Acceptance Probability: 10.227272727272728 %
# Epoch 440 W Acceptance Probability: 65.9090909090909 %
# ********** Accepted: 7 **********
# Epoch 450 A Acceptance Probability: 10.222222222222223 %
# Epoch 450 W Acceptance Probability: 66.0 %
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# Epoch 460 A Acceptance Probability: 10.434782608695652 %
# Epoch 460 W Acceptance Probability: 66.08695652173913 %
# Epoch 470 A Acceptance Probability: 10.212765957446807 %
# Epoch 470 W Acceptance Probability: 66.17021276595744 %
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 480 A Acceptance Probability: 10.416666666666668 %
# Epoch 480 W Acceptance Probability: 66.25 %
# ********** Accepted: 6 **********
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# Epoch 490 A Acceptance Probability: 10.816326530612246 %
# Epoch 490 W Acceptance Probability: 66.53061224489795 %
# ********** Accepted: 5 **********
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 500 A Acceptance Probability: 11.200000000000001 %
# Epoch 500 W Acceptance Probability: 66.8 %
# ********** Accepted: 6 **********
# Epoch 510 A Acceptance Probability: 11.176470588235295 %
# Epoch 510 W Acceptance Probability: 67.25490196078432 %
# Epoch 520 A Acceptance Probability: 10.961538461538462 %
# Epoch 520 W Acceptance Probability: 67.11538461538461 %
# Epoch 530 A Acceptance Probability: 10.754716981132075 %
# Epoch 530 W Acceptance Probability: 67.35849056603773 %
# Epoch 540 A Acceptance Probability: 10.555555555555555 %
# Epoch 540 W Acceptance Probability: 67.96296296296296 %
# Epoch 550 A Acceptance Probability: 10.363636363636363 %
# Epoch 550 W Acceptance Probability: 67.81818181818183 %
# ********** Accepted: 5 **********
# Epoch 560 A Acceptance Probability: 10.357142857142858 %
# Epoch 560 W Acceptance Probability: 67.32142857142858 %
# ********** Accepted: 6 **********
# Epoch 570 A Acceptance Probability: 10.350877192982457 %
# Epoch 570 W Acceptance Probability: 67.71929824561404 %
# ********** Accepted: 7 **********
# Epoch 580 A Acceptance Probability: 10.344827586206897 %
# Epoch 580 W Acceptance Probability: 67.58620689655173 %
# Epoch 590 A Acceptance Probability: 10.16949152542373 %
# Epoch 590 W Acceptance Probability: 67.28813559322035 %
# Epoch 600 A Acceptance Probability: 10.0 %
# Epoch 600 W Acceptance Probability: 67.5 %
# Epoch 610 A Acceptance Probability: 9.836065573770492 %
# Epoch 610 W Acceptance Probability: 67.70491803278689 %
# Epoch 620 A Acceptance Probability: 9.67741935483871 %
# Epoch 620 W Acceptance Probability: 67.74193548387096 %
# ********** Accepted: 8 **********
# ********** Accepted: 9 **********
# Epoch 630 A Acceptance Probability: 9.841269841269842 %
# Epoch 630 W Acceptance Probability: 67.77777777777779 %
# ********** Accepted: 10 **********
# Epoch 640 A Acceptance Probability: 9.84375 %
# Epoch 640 W Acceptance Probability: 67.65625 %
# ********** Accepted: 9 **********
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# Epoch 650 A Acceptance Probability: 10.153846153846153 %
# Epoch 650 W Acceptance Probability: 67.6923076923077 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 660 A Acceptance Probability: 10.606060606060606 %
# Epoch 660 W Acceptance Probability: 68.18181818181817 %
# ********** Accepted: 8 **********
# ********** Accepted: 9 **********
# Epoch 670 A Acceptance Probability: 10.746268656716417 %
# Epoch 670 W Acceptance Probability: 68.2089552238806 %
# ********** Accepted: 8 **********
# Epoch 680 A Acceptance Probability: 10.735294117647058 %
# Epoch 680 W Acceptance Probability: 67.94117647058823 %
# ********** Accepted: 9 **********
# Epoch 690 A Acceptance Probability: 10.72463768115942 %
# Epoch 690 W Acceptance Probability: 67.97101449275362 %
# ********** Accepted: 8 **********
# Epoch 700 A Acceptance Probability: 10.714285714285714 %
# Epoch 700 W Acceptance Probability: 67.57142857142857 %
# ********** Accepted: 9 **********
# Epoch 710 A Acceptance Probability: 10.704225352112676 %
# Epoch 710 W Acceptance Probability: 67.88732394366197 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# ********** Accepted: 6 **********
# Epoch 720 A Acceptance Probability: 10.972222222222221 %
# Epoch 720 W Acceptance Probability: 68.05555555555556 %
# ********** Accepted: 7 **********
# Epoch 730 A Acceptance Probability: 10.95890410958904 %
# Epoch 730 W Acceptance Probability: 67.94520547945206 %
# Epoch 740 A Acceptance Probability: 10.81081081081081 %
# Epoch 740 W Acceptance Probability: 67.97297297297298 %
# ********** Accepted: 8 **********
# ********** Accepted: 9 **********
# Epoch 750 A Acceptance Probability: 10.933333333333334 %
# Epoch 750 W Acceptance Probability: 68.26666666666667 %
# ********** Accepted: 10 **********
# ********** Accepted: 9 **********
# ********** Accepted: 8 **********
# Epoch 760 A Acceptance Probability: 11.18421052631579 %
# Epoch 760 W Acceptance Probability: 68.42105263157895 %
# Epoch 770 A Acceptance Probability: 11.03896103896104 %
# Epoch 770 W Acceptance Probability: 68.57142857142857 %
# ********** Accepted: 7 **********
# Epoch 780 A Acceptance Probability: 11.025641025641026 %
# Epoch 780 W Acceptance Probability: 68.84615384615384 %
# ********** Accepted: 6 **********
# ********** Accepted: 7 **********
# Epoch 790 A Acceptance Probability: 11.139240506329113 %
# Epoch 790 W Acceptance Probability: 68.9873417721519 %
# Epoch 800 A Acceptance Probability: 11.0 %
# Epoch 800 W Acceptance Probability: 68.875 %
# Epoch 810 A Acceptance Probability: 10.864197530864198 %
# Epoch 810 W Acceptance Probability: 69.25925925925925 %
# ********** Accepted: 8 **********
# Epoch 820 A Acceptance Probability: 10.853658536585366 %
# Epoch 820 W Acceptance Probability: 69.14634146341463 %
# ********** Accepted: 9 **********
# Epoch 830 A Acceptance Probability: 10.843373493975903 %
# Epoch 830 W Acceptance Probability: 69.39759036144578 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# Epoch 840 A Acceptance Probability: 10.952380952380953 %
# Epoch 840 W Acceptance Probability: 69.64285714285714 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# Epoch 850 A Acceptance Probability: 11.058823529411764 %
# Epoch 850 W Acceptance Probability: 70.0 %
# ********** Accepted: 8 **********
# ********** Accepted: 7 **********
# ********** Accepted: 8 **********
# Epoch 860 A Acceptance Probability: 11.27906976744186 %
# Epoch 860 W Acceptance Probability: 70.0 %
# ********** Accepted: 9 **********
# ********** Accepted: 10 **********
# Epoch 870 A Acceptance Probability: 11.379310344827587 %
# Epoch 870 W Acceptance Probability: 69.88505747126436 %
# ********** Accepted: 9 **********
# Epoch 880 A Acceptance Probability: 11.363636363636363 %
# Epoch 880 W Acceptance Probability: 69.6590909090909 %
# ********** Accepted: 10 **********
# Epoch 890 A Acceptance Probability: 11.348314606741573 %
# Epoch 890 W Acceptance Probability: 69.7752808988764 %
# ********** Accepted: 11 **********
# ********** Accepted: 10 **********
# Epoch 900 A Acceptance Probability: 11.444444444444445 %
# Epoch 900 W Acceptance Probability: 69.66666666666667 %
# ********** Accepted: 11 **********
# Epoch 910 A Acceptance Probability: 11.428571428571429 %
# Epoch 910 W Acceptance Probability: 69.78021978021978 %
# Epoch 920 A Acceptance Probability: 11.304347826086957 %
# Epoch 920 W Acceptance Probability: 69.67391304347827 %
# ********** Accepted: 12 **********
# ********** Accepted: 11 **********
# ********** Accepted: 10 **********
# Epoch 930 A Acceptance Probability: 11.505376344086022 %
# Epoch 930 W Acceptance Probability: 69.78494623655914 %
# ********** Accepted: 9 **********
# ********** Accepted: 10 **********
# Epoch 940 A Acceptance Probability: 11.595744680851064 %
# Epoch 940 W Acceptance Probability: 69.57446808510637 %
# ********** Accepted: 9 **********
# Epoch 950 A Acceptance Probability: 11.578947368421053 %
# Epoch 950 W Acceptance Probability: 69.47368421052632 %
# ********** Accepted: 10 **********
# ********** Accepted: 9 **********
# Epoch 960 A Acceptance Probability: 11.666666666666666 %
# Epoch 960 W Acceptance Probability: 69.6875 %
# ********** Accepted: 10 **********
# Epoch 970 A Acceptance Probability: 11.649484536082474 %
# Epoch 970 W Acceptance Probability: 69.58762886597938 %
# ********** Accepted: 9 **********
# ********** Accepted: 8 **********
# Epoch 980 A Acceptance Probability: 11.73469387755102 %
# Epoch 980 W Acceptance Probability: 69.18367346938776 %
# Epoch 990 A Acceptance Probability: 11.616161616161616 %
# Epoch 990 W Acceptance Probability: 68.88888888888889 %
# Epoch 1000 A Acceptance Probability: 11.5 %
# Epoch 1000 W Acceptance Probability: 68.89999999999999 %

# %%
#Log Posterior Score Chart
obs_master = choicemap()::ChoiceMap
for i=1:length(y)
    obs_master[(:y,i)] = y[i]
end
obs = obs_master;

plot([get_score(trace) for trace in traces])
plt.title("NUTS Score: MNIST Classification")
plt.xlabel("Iteration")
plt.ylabel("Log Posterior");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Node Count Histogram

########################
#Bar Plot of l estimates
########################

ks = [traces[i][(:k,1)] for i in 1:length(traces)]
counts = [sum([ks[i] == j for i in 1:length(ks)]) for j in k_list]

barlist=bar(k_list,counts)
for i in 1:k_range
    barlist[i].set_color([0.8,0.0,0.0])
end
#barlist[2].set_color([0.0,0.8,0.1])

plt.title("MNIST Classification: Number of Hidden Nodes")
plt.xlabel("Number of Nodes")
plt.ylabel("Frequency");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Node Count Chart

plot([trace[(:k,1)] for trace in traces])
plt.title("MNIST Classification: Number of Hidden Nodes")
plt.xlabel("Iteration")
plt.ylabel("Node Count");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Plot Training Accuracy
accs = []
accs2 = []
dists = []
dists2 = []
for i = 1:length(traces)
    trace = traces[i]
    test_labels = G(xt,trace)
    results = label_output(test_labels)
    test_acc = sum([y[i] == results[i] for i=1:length(y)])/length(y)
    test_dist = sum([euclidean(yt[:,j],test_labels[:,j]) for j=1:length(y)])
    push!(accs,test_acc)
    push!(dists,test_dist)
    
    trace = traces[i]
    test_labels = G(xt_test,trace)
    results = label_output(test_labels)
    test_acc = sum([y_test[i] == results[i] for i=1:length(y_test)])/length(y_test)
    test_dist = sum([euclidean(yzt[:,j],test_labels[:,j]) for j=1:length(y)])
    push!(accs2,test_acc)
    push!(dists2,test_dist)
end

plot(accs,label="Train")
plot(accs2,label="Test",c="lightgreen")
plt.title("NUTS Accuracy: MNIST Classification Accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plot(dists,label="Train")
plot(dists2,label="Test",color="lightgreen")
plt.title("NUTS Euclidean Distance")
plt.xlabel("Iteration")
plt.ylabel("Euclidean Distance")
plt.legend();
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Marginalize Probabilities - Train Set
j = 200
targets = zeros(length(traces)-j,c,N)
for i=j:length(traces)-j
    trace = traces[i]
    labels = G(xt,trace)
    targets[i-j+1,:,:] = labels
end

sums = sum(targets,dims=1)[1,:,:]./(length(traces)-j)
guesses = [findmax(sums[:,i])[2] for i=1:N]
test_acc = sum([y[i] == guesses[i] for i=1:length(y)])
# Out:
# 174

# %%
#Marginalize Probabilities - Test Set
j = 200
targets = zeros(length(traces)-j,c,N)
for i=j:length(traces)-j
    trace = traces[i]
    labels = G(xt_test,trace)
    targets[i-j+1,:,:] = labels
end

sums = sum(targets,dims=1)[1,:,:]./(length(traces)-j)
guesses = [findmax(sums[:,i])[2] for i=1:N]
test_acc = sum([yz[i] == guesses[i] for i=1:length(yz)])
# Out:
# 172

# %%
function plot_grid(data,scores,alpha=1.0)
    PyPlot.scatter(data[:,1],data[:,2],c=scores,alpha=alpha,cmap="PRGn")
    #PyPlot.colorbar()
end

function tracegrid(traces, samples=800, low=-3.0, high=3.0)
    d=2
    n=100
    starting_iter = 200
    r = range(low, high, length = n)
    
    iter = Iterators.product((r for _ in 1:d)...)
    grid= vec([collect(i) for i in iter])
    grid_raw = reduce(hcat, getindex.(grid,i) for i in eachindex(grid[1]))
    grid2 = transpose(grid_raw)
    z_master = zeros(length(grid2[1,:]))
    
    for i=1:samples
        j = rand((starting_iter,length(traces)))
        trace = traces[j]
        z = G(grid2,trace)[1,:]
        #display(z)
        z_master += (z ./ samples)
    end
    plot_grid(grid_raw, z_master)
end

tracegrid(traces)
plot_data_classifier(x_raw,classes)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
weights = [trace[(:W,1)][1] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][2] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][3] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][48] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][57] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][58] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][59] for trace in traces]
plot(weights)
weights = [trace[(:W,1)][60] for trace in traces]
plot(weights)
# Out:
# BoundsError: attempt to access 2-element Array{Float64,1} at index [3]
#
# Stacktrace:
#  [1] getindex(::Array{Float64,1}, ::Int64) at ./array.jl:788
#  [2] (::var"#1822#1823")(::Gen.DynamicDSLTrace{DynamicDSLFunction{Any}}) at ./none:0
#  [3] iterate at ./generator.jl:47 [inlined]
#  [4] collect(::Base.Generator{Array{Any,1},var"#1822#1823"}) at ./array.jl:665
#  [5] top-level scope at In[213]:5

# %%
plot([1/trace[(:τᵦ,2)] for trace in traces])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb219dfa150>
